# %% [markdown]
# # General Dataset

# %% [markdown]
# # Government Dataset and Testing Dataset

# %% [markdown]
# # Detailed Datasets

# %%
import pandas as pd
import os

# %% [markdown]
# ## 1 France

# %%
PATH_COVID_FR = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/donnees-hospitalieres-covid19-2020-04-25-19h00.csv')
PATH_COVID_FR_METADATA = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/metadonnees-donnees-hospitalieres-covid19.csv')

PATH_COVID_FR_AGE_SEXE = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/donnees-hospitalieres-classe-age-covid19-2020-04-25-19h00.csv')
PATH_COVID_FR_AGE_METADATA = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/metadonnees-donnees-hospitalieres-covid19-classes-age.csv')
PATH_COVID_FR_SEXE_METADATA = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/metadonnees-sexe.csv')

PATH_COVID_FR_HOSP = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/donnees-hospitalieres-nouveaux-covid19-2020-04-25-19h00.csv')
PATH_COVID_FR_HOSP_METADATA = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/metadonnees-hospit-incid.csv')

# %%
covid_fr = pd.read_csv(PATH_COVID_FR, sep=';')
covid_fr_metadata = pd.read_csv(PATH_COVID_FR_METADATA, sep=';')

covid_fr_age_sexe = pd.read_csv(PATH_COVID_FR_AGE_SEXE, sep=';')
covid_fr_age_metadata = pd.read_csv(PATH_COVID_FR_AGE_METADATA, sep=';')
covid_fr_sexe_metadata = pd.read_csv(PATH_COVID_FR_SEXE_METADATA)

covid_fr_hosp = pd.read_csv(PATH_COVID_FR_HOSP, sep=';')
covid_fr_hosp_metadata = pd.read_csv(PATH_COVID_FR_HOSP_METADATA, sep=';')

# %%
covid_fr.head()
# Out:
#   dep  sexe        jour  hosp  rea  rad  dc
# 0  01     0  2020-03-18     2    0    1   0
# 1  01     1  2020-03-18     1    0    1   0
# 2  01     2  2020-03-18     1    0    0   0
# 3  02     0  2020-03-18    41   10   18  11
# 4  02     1  2020-03-18    19    4   11   6

# %%
covid_fr_metadata
# Out:
#   Colonne          Type                                      Description_FR  \
# 0     dep        integer                                        Département
# 1    sexe        integer                                              Sexe
# 2    jour  string($date)                              Date de notification
# 3    hosp        integer     Nombre de personnes actuellement hospitalisées
# 4     rea        integer  Nombre de personnes actuellement en réanimatio...
# 5     rad        integer   Nombre cumulé de personnes retournées à domicile
# 6      dc        integer    Nombre cumulé de personnes décédées à l'hôpital
#
#                                       Description_EN     Exemple
# 0                                         Department           1
# 1                                               Sex            0
# 2                                     Date of notice  18/03/2020
# 3            Number of people currently hospitalized           2
# 4  Number of people currently in resuscitation or...           0
# 5         Total amount of patient that returned home           1
# 6              Total amout of deaths at the hospital           0

# %%
covid_fr_age_sexe.head()
# Out:
#    reg  cl_age90        jour  hosp  rea  rad  dc
# 0    1         0  2020-04-07    34   17   43   8
# 1    1         9  2020-04-07     0    0    0   0
# 2    1        19  2020-04-07     0    0    0   0
# 3    1        29  2020-04-07     0    0    1   0
# 4    1        39  2020-04-07     1    1    3   0

# %%
covid_fr_age_metadata
# Out:
#      Colonne          Type   \
# 0        reg        integer
# 1   cl_age90        integer
# 2       jour  string($date)
# 3       hosp        integer
# 4        rea        integer
# 5        rad        integer
# 6         dc        integer
# 7        NaN            NaN
# 8        NaN            NaN
# 9        NaN            NaN
# 10       NaN            NaN
# 11       NaN            NaN
# 12       NaN            NaN
# 13       NaN            NaN
# 14       NaN            NaN
# 15       NaN            NaN
# 16       NaN            NaN
# 17       NaN            NaN
# 18       NaN            NaN
# 19       NaN            NaN
# 20       NaN            NaN
# 21       NaN            NaN
# 22       NaN            NaN
# 23       NaN            NaN
# 24       NaN            NaN
#
#                                        Description_FR  \
# 0                                              Region
# 1                                         Classe age
# 2                               Date de notification
# 3      Nombre de personnes actuellement hospitalisées
# 4   Nombre de personnes actuellement en réanimatio...
# 5    Nombre cumulé de personnes retournées à domicile
# 6                 Nombre cumulé de personnes décédées
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                        Description_EN     Exemple  Unnamed: 5  \
# 0                                              Region           1         NaN
# 1                                           Age group           9         NaN
# 2                                      Date of notice  18/03/2020         NaN
# 3             Number of people currently hospitalized           2         NaN
# 4   Number of people currently in resuscitation or...           0         NaN
# 5          Total amount of patient that returned home           1         NaN
# 6                               Total amout of deaths           0         NaN
# 7                                                 NaN         NaN         NaN
# 8                                                 NaN         NaN         NaN
# 9                                                 NaN         NaN         NaN
# 10                                                NaN         NaN         NaN
# 11                                                NaN         NaN         NaN
# 12                                                NaN         NaN         NaN
# 13                                                NaN         NaN         NaN
# 14                                                NaN         NaN         NaN
# 15                                                NaN         NaN         NaN
# 16                                                NaN         NaN         NaN
# 17                                                NaN         NaN         NaN
# 18                                                NaN         NaN         NaN
# 19                                                NaN         NaN         NaN
# 20                                                NaN         NaN         NaN
# 21                                                NaN         NaN         NaN
# 22                                                NaN         NaN         NaN
# 23                                                NaN         NaN         NaN
# 24                                                NaN         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0          NaN         NaN         NaN         NaN          NaN          NaN
# 1          NaN         NaN         NaN         NaN          NaN          NaN
# 2          NaN         NaN         NaN         NaN          NaN          NaN
# 3          NaN         NaN         NaN         NaN          NaN          NaN
# 4          NaN         NaN         NaN         NaN          NaN          NaN
# 5          NaN         NaN         NaN         NaN          NaN          NaN
# 6          NaN         NaN         NaN         NaN          NaN          NaN
# 7          NaN         NaN         NaN         NaN          NaN          NaN
# 8          NaN         NaN         NaN         NaN          NaN          NaN
# 9          NaN         NaN         NaN         NaN          NaN          NaN
# 10         NaN         NaN         NaN         NaN          NaN          NaN
# 11         NaN         NaN         NaN         NaN          NaN          NaN
# 12         NaN         NaN         NaN         NaN          NaN          NaN
# 13         NaN         NaN         NaN         NaN          NaN          NaN
# 14         NaN         NaN         NaN         NaN          NaN          NaN
# 15         NaN         NaN         NaN         NaN          NaN          NaN
# 16         NaN         NaN         NaN         NaN          NaN          NaN
# 17         NaN         NaN         NaN         NaN          NaN          NaN
# 18         NaN         NaN         NaN         NaN          NaN          NaN
# 19         NaN         NaN         NaN         NaN          NaN          NaN
# 20         NaN         NaN         NaN         NaN          NaN          NaN
# 21         NaN         NaN         NaN         NaN          NaN          NaN
# 22         NaN         NaN         NaN         NaN          NaN          NaN
# 23         NaN         NaN         NaN         NaN          NaN          NaN
# 24         NaN         NaN         NaN         NaN          NaN          NaN
#
#     Unnamed: 12
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN

# %%
covid_fr_sexe_metadata
# Out:
#    {\rtf1\ansi\ansicpg1252\cocoartf1671\cocoasubrtf600
# 0           {\fonttbl\f0\fswiss\fcharset0 Helvetica;}
# 1               {\colortbl;\red255\green255\blue255;}
# 2                             {\*\expandedcolortbl;;}
# 3   \paperw11900\paperh16840\margl1440\margr1440\v...
# 4   \pard\tx566\tx1133\tx1700\tx2267\tx2834\tx3401...
# 5                           \f0\fs24 \cf0 Code ; Sexe
# 6                                                   \
# 7                                  0; femmes + hommes
# 8                                                   \
# 9                                           1;hommes\
# 10                                          2;femmes}

# %%
covid_fr_hosp.head()
# Out:
#   dep        jour  incid_hosp  incid_rea  incid_dc  incid_rad
# 0  01  2020-03-19           1          0         0          0
# 1  01  2020-03-20           0          0         0          1
# 2  01  2020-03-21           3          0         0          0
# 3  01  2020-03-22           3          1         0          1
# 4  01  2020-03-23          14          1         0          5

# %%
covid_fr_hosp_metadata
# Out:
#       Colonne          Type   \
# 0         dep        integer
# 1        jour  string($date)
# 2  incid_hosp        string
# 3   incid_rea        integer
# 4    incid_dc        integer
# 5   incid_rad        integer
# 6         NaN            NaN
# 7         NaN            NaN
# 8         NaN            NaN
# 9         NaN            NaN
#
#                                       Description_FR  \
# 0                                        Département
# 1                              Date de notification
# 2  Nombre quotidien de personnes nouvellement hos...
# 3  Nombre quotidien de nouvelles admissions en ré...
# 4  Nombre quotidien de personnes nouvellement déc...
# 5   Nombre quotidien de nouveaux retours à domicile
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                    Description_EN     Exemple
# 0                                      Department           1
# 1                                  Date of notice  19/03/2020
# 2      Daily number of newly hospitalized persons           1
# 3  Daily number of new intensive care admissions            1
# 4          Daily number of newly deceased persons           1
# 5               Daily number of new home returns            2
# 6                                             NaN         NaN
# 7                                             NaN         NaN
# 8                                             NaN         NaN
# 9                                             NaN         NaN

# %% [markdown]
# ## 2 Germany

# %%
PATH_COVID_GER = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/RKI_COVID19.csv')

# %%
covid_ger = pd.read_csv(PATH_COVID_GER)

# %%
covid_ger.head()
# Out:
#    IdBundesland          Bundesland     Landkreis Altersgruppe Geschlecht  \
# 0             1  Schleswig-Holstein  LK Steinburg      A15-A34          W
# 1             1  Schleswig-Holstein  LK Steinburg      A15-A34          W
# 2             1  Schleswig-Holstein  LK Steinburg      A15-A34          W
# 3             1  Schleswig-Holstein  LK Steinburg      A15-A34          W
# 4             1  Schleswig-Holstein  LK Steinburg      A15-A34          W
#
#    AnzahlFall  AnzahlTodesfall  ObjectId                Meldedatum  \
# 0           1                0   3650921  2020-03-25T00:00:00.000Z
# 1           1                0   3650922  2020-03-27T00:00:00.000Z
# 2           1                0   3650923  2020-04-01T00:00:00.000Z
# 3           1                0   3650924  2020-04-06T00:00:00.000Z
# 4           1                0   3650925  2020-04-07T00:00:00.000Z
#
#    IdLandkreis             Datenstand  NeuerFall  NeuerTodesfall  \
# 0         1061  25.04.2020, 00:00 Uhr          0              -9
# 1         1061  25.04.2020, 00:00 Uhr          0              -9
# 2         1061  25.04.2020, 00:00 Uhr          0              -9
# 3         1061  25.04.2020, 00:00 Uhr          0              -9
# 4         1061  25.04.2020, 00:00 Uhr          0              -9
#
#                    Refdatum  NeuGenesen  AnzahlGenesen
# 0  2020-03-16T00:00:00.000Z           0              1
# 1  2020-03-22T00:00:00.000Z           0              1
# 2  2020-03-21T00:00:00.000Z           0              1
# 3  2020-03-22T00:00:00.000Z           0              1
# 4  2020-03-31T00:00:00.000Z           0              1

# %% [markdown]
# ## 3 Belgium

# %%
PATH_COVID_BE = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/COVID19BE.xlsx')
PATH_COVID_BE_HOSP = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/COVID19BE_HOSP.csv')
PATH_COVID_BE_DEATHS = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/COVID19BE_MORT.csv')
PATH_COVID_BE_TESTS = os.path.expanduser('~/Documents/GitHub/com-480-project-pouletpanier/data/detailed_data/COVID19BE_tests.csv')

# %%
covid_be = pd.read_excel(PATH_COVID_BE)
covid_be_hops = pd.read_csv(PATH_COVID_BE_HOSP, encoding = "ISO-8859-1")
covid_be_deaths = pd.read_csv(PATH_COVID_BE_DEATHS)
covid_be_tests = pd.read_csv(PATH_COVID_BE_TESTS)

# %%
covid_be.head()
# Out:
#          DATE  PROVINCE    REGION AGEGROUP SEX  CASES
# 0  2020-03-01  Brussels  Brussels    10-19   M      1
# 1  2020-03-01  Brussels  Brussels    10-19   F      1
# 2  2020-03-01  Brussels  Brussels    20-29   M      1
# 3  2020-03-01  Brussels  Brussels    30-39   F      1
# 4  2020-03-01  Brussels  Brussels    40-49   F      1

# %%
covid_be_hops.head()
# Out:
#          DATE   PROVINCE    REGION  NR_REPORTING  TOTAL_IN  TOTAL_IN_ICU  \
# 0  2020-03-15  Antwerpen  Flanders            14        50             9
# 1  2020-03-15   Brussels  Brussels            14        58            11
# 2  2020-03-15    Hainaut  Wallonia            15        56            13
# 3  2020-03-15    Limburg  Flanders             7        20             6
# 4  2020-03-15      Liège  Wallonia            12        22             2
#
#    TOTAL_IN_RESP  TOTAL_IN_ECMO  NEW_IN  NEW_OUT
# 0              4              0       8        8
# 1              8              0       7        2
# 2             11              1      26        1
# 3              3              0       9        3
# 4              1              0       4        1

# %%
covid_be_deaths.head()
# Out:
#          DATE    REGION AGEGROUP SEX  DEATHS
# 0  2020-03-10  Brussels      85+   F       1
# 1  2020-03-11  Flanders      85+   F       1
# 2  2020-03-11  Brussels    75-84   M       1
# 3  2020-03-11  Brussels      85+   F       1
# 4  2020-03-12  Brussels    75-84   M       1

# %%
covid_be_tests.head()
# Out:
#          DATE  TESTS
# 0  2020-03-01     56
# 1  2020-03-02    278
# 2  2020-03-03    484
# 3  2020-03-04    656
# 4  2020-03-05    713
